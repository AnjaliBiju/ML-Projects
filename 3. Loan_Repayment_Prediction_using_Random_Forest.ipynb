# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjaliBiju/ML-Projects/blob/main/Loan_Repayment_Prediction_using_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicting Loan Repayment Status with Random Forest (LendingClub Dataset)

# %% [markdown]
# Here's what the columns represent:
#
# *   **credit.policy**: 1 if the customer meets the credit underwriting criteria of LendingClub.com, and 0 otherwise.
# *   **purpose**: The purpose of the loan (takes values "credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other").
# *   **int.rate**: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# *   **installment**: The monthly installments owed by the borrower if the loan is funded.
# *   **log.annual.inc**: The natural log of the self-reported annual income of the borrower.
# *   **dti**: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# *   **fico**: The FICO credit score of the borrower.
# *   **days.with.cr.line**: The number of days the borrower has had a credit line.
# *   **revol.bal**: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# *   **revol.util**: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# *   **inq.last.6mths**: The borrower's number of inquiries by creditors in the last 6 months.
# *   **delinq.2yrs**: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# *   **pub.rec**: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5ed4d7f2-0fee-43d6-83e6-4ef217738a4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ed4d7f2-0fee-43d6-83e6-4ef217738a4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
loans= pd.read_csv('loan_data.csv')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
sns.countplot(x='credit.policy',data=loans)
#most people satisfy the credit policy
# Out:
# <Axes: xlabel='credit.policy', ylabel='count'>

# %%
#histogram of 2 FICO distributions overlapping each other, one for each credit.policy outcome

#filter based on credit.policy outcome
credit1= loans[loans['credit.policy']==1]['fico']
credit0= loans[loans['credit.policy']==0]['fico']

#plot overlapping histograms
plt.hist(credit1,bins=30,alpha=0.5,color='blue',label='credit.policy 1')
plt.hist(credit0,bins=30,alpha=0.5,color='red',label='credit.policy 0')

plt.xlabel('FICO')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
#Histogram of 2 FICO distributions overalpping each other, based on the not.fully.paid column

#filter based on not.fully.paid column
not_paid1=loans[loans['not.fully.paid']==1]['fico']
not_paid0=loans[loans['not.fully.paid']==0]['fico']

#plot overlapping histograms
plt.hist(not_paid1,bins=30,alpha=0.5,color='blue',label='not.fully.paid = 1')
plt.hist(not_paid0,bins=30,alpha=0.5,color='red',label='not.fully.paid = 0')

plt.xlabel('FICO')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
#Counts of loan by purpose.. hue=not.fully.paid
plt.figure(figsize=(12,6))
sns.countplot(x='purpose',data=loans,hue='not.fully.paid',palette='Set1')
# Out:
# <Axes: xlabel='purpose', ylabel='count'>

# %%
plt.figure(figsize=(3,2))
sns.jointplot(x='fico',y='int.rate',data=loans,kind='scatter',color='purple')

# %%
sns.lmplot(x='fico',y='int.rate',data=loans,hue='credit.policy',col='not.fully.paid',palette='Set1')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
#pupose column is categorical .. so we neeed to transform them using dummy variables so sklearn
#will be able to understand them

# %%
cat_feats=['purpose']

# %%
final_data=pd.get_dummies(loans,columns=cat_feats,drop_first=True)
#pd.get_dummies() converts categorical values into dummy/indicator variables
# and that too only for the columns specified
#drop_first=True drops the first category in each feature to avoid dummy variables

# %%
from sklearn.model_selection import train_test_split

# %%
X= final_data.drop('not.fully.paid',axis=1)
y=final_data['not.fully.paid']

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# ## Training a Decision Tree model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predictions and Evaluations of Decision Tree

# %%
predictions= dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84      2431
#            1       0.19      0.23      0.21       443
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.75      0.73      0.74      2874

# %%
print(confusion_matrix(y_test,predictions))
#TN FP
#FN TP
# Out:
# [[1991  440]
#  [ 342  101]]

# %% [markdown]
# ## Training the Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred= rfc.predict(X_test)

# %%
rfc_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.60      0.03      0.05       443
#
#     accuracy                           0.85      2874
#    macro avg       0.72      0.51      0.48      2874
# weighted avg       0.81      0.85      0.78      2874

# %%
print(confusion_matrix(y_test,rfc_pred))
#TN FP
#FN TP
# Out:
# [[2423    8]
#  [ 431   12]]

# %% [markdown]
# # Conclusion

# %% [markdown]
# * Decision Tree achieved 73% accuracy, performing well on the majority class (not.fully.paid = 0) but with low recall (0.23) for the minority class (not.fully.paid = 1).
#
# * Random Forest improved accuracy to 85%, correctly classifying most fully paid loans, but recall for the minority class remained very low (0.03).
#
# * Both models show a strong bias toward the majority class due to class imbalance in the dataset.
#
# * To enhance minority class prediction, methods like SMOTE oversampling, class weighting, or advanced ensemble techniques should be applied.
